# %%
import os
import pandas as pd
import tensorflow as tf

# %%
os.chdir("C:\\Users\\yana1\\Downloads")

# %%
data = pd.read_csv('thesisdata_cleaned_fullsample.csv')

data = data.drop(columns = ['Unnamed: 0'])
data.head()
# Out:
#           type gender_guessed  Height  Width   is_flat  age  years_selling  \
# 0  Unique work         female    27.6   27.6  Not flat  0.0            1.0
# 1  Unique work         female    19.7   19.7  Not flat  0.0            3.0
# 2  Unique work         female    23.6   23.6  Not flat  0.0            3.0
# 3  Unique work         female    15.7   11.8  Not flat  4.0            5.0
# 4  Unique work        unknown    15.7   15.7  Not flat  4.0            5.0
#
#   Uniqueness is_signed      gallery  price_numeric painting  \
# 0     Unique    signed  independent         3158.0    other
# 1     Unique    signed  independent         2065.0    other
# 2     Unique    signed  independent         3522.0    other
# 3     Unique    signed      gallery          644.0      oil
# 4     Unique    signed  independent          838.0    other
#
#   description_present location                     image_path
# 0             Present   France  images_thesis\2313827_1_m.jpg
# 1             Present   France  images_thesis\2328028_1_m.jpg
# 2             Present   France  images_thesis\2299335_1_m.jpg
# 3             Present    other  images_thesis\1118562_1_m.jpg
# 4             Present   France  images_thesis\1241121_1_m.jpg

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20917 entries, 0 to 20916
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   type                 20917 non-null  object
#  1   gender_guessed       20917 non-null  object
#  2   Height               20917 non-null  float64
#  3   Width                20917 non-null  float64
#  4   is_flat              20917 non-null  object
#  5   age                  20917 non-null  float64
#  6   years_selling        20917 non-null  float64
#  7   Uniqueness           20917 non-null  object
#  8   is_signed            20917 non-null  object
#  9   gallery              20917 non-null  object
#  10  price_numeric        20917 non-null  float64
#  11  painting             20917 non-null  object
#  12  description_present  20917 non-null  object
#  13  location             20917 non-null  object
#  14  image_path           20917 non-null  object
# dtypes: float64(5), object(10)
# memory usage: 2.4+ MB
# None

# %%
numeric = data.select_dtypes(include = 'number').columns.drop('price_numeric')
categorical = data.select_dtypes(include = 'object').drop(columns = ['image_path']).columns

print(numeric)
print(categorical)
# Out:
# Index(['Height', 'Width', 'age', 'years_selling'], dtype='object')
# Index(['type', 'gender_guessed', 'is_flat', 'Uniqueness', 'is_signed',
#        'gallery', 'painting', 'description_present', 'location'],
#       dtype='object')

# %%
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(data[numeric].to_numpy())   # learn mean + variance

string_lookups = {}

for col in categorical:
    lookup = tf.keras.layers.StringLookup(output_mode="int")
    lookup.adapt(data[col])    # learn unique categories
    string_lookups[col] = lookup

one_hot_encoders = {}

for col in categorical:
    encoder = tf.keras.layers.CategoryEncoding(
        num_tokens=string_lookups[col].vocabulary_size(),
        output_mode="one_hot"
    )
    one_hot_encoders[col] = encoder

# %%
# preprocess, build the model

encoded_features = []

numeric_data = tf.keras.layers.Concatenate(axis=-1)(
    [inputs[col] for col in numeric]
)
encoded_numeric = normalizer(numeric_data)
encoded_features.append(encoded_numeric)


for col in categorical:
    int_encoded = string_lookups[col](inputs[col])       
    one_hot = one_hot_encoders[col](int_encoded)         
    encoded_features.append(one_hot)

x = tf.keras.layers.concatenate(encoded_features)

# 4.4 — Build the dense neural network
x = tf.keras.layers.Dense(128, activation="relu")(x)
x = tf.keras.layers.Dense(64, activation="relu")(x)
x = tf.keras.layers.Dense(32, activation="relu")(x)

output = tf.keras.layers.Dense(1)(x)

model = tf.keras.Model(inputs=inputs, outputs=output)
model.compile(optimizer="adam", loss="mse")

# %%
#test and debug

sample = data.sample(100, random_state=42).copy()


X_debug = {}

for col in numeric:
    X_debug[col] = sample[col].values

for col in categorical:
    X_debug[col] = sample[col].values

# %%
X_debug
# Out:
# {'Height': array([20.  , 14.6 , 39.4 , 12.  , 21.7 , 15.7 , 13.8 , 36.2 , 40.6 ,
#         18.9 , 41.3 , 27.6 , 39.4 , 63.8 , 35.4 , 10.2 , 19.7 , 22.6 ,
#         22.4 , 23.6 , 31.5 , 55.9 , 27.  , 55.1 , 31.5 , 44.9 , 29.  ,
#         22.  , 43.3 , 17.75, 43.3 , 19.7 , 47.6 , 30.  , 17.7 , 15.7 ,
#         10.2 , 27.6 ,  7.1 , 31.5 , 16.1 , 23.6 , 32.  , 23.6 , 19.7 ,
#         22.8 , 24.4 ,  9.4 ,  0.4 , 55.1 , 23.6 , 10.6 , 25.6 , 19.7 ,
#         19.  , 47.2 , 35.  , 31.5 , 31.9 , 23.6 , 39.4 , 39.4 , 19.7 ,
#         19.7 ,  7.9 , 19.7 , 55.1 , 19.7 , 15.7 , 31.5 , 19.7 ,  9.8 ,
#         23.6 , 19.7 , 17.7 , 31.5 , 31.5 , 13.  , 37.6 , 23.6 , 30.7 ,
#         23.6 , 31.5 , 15.9 , 35.4 , 23.6 ,  7.1 , 27.6 , 19.6 , 27.6 ,
#         13.  , 30.  , 51.2 , 39.4 , 35.4 , 39.4 , 21.7 , 35.  , 40.2 ,
#         29.9 ]),
#  'Width': array([24.  , 25.2 , 39.4 ,  8.  , 13.  , 15.7 , 19.7 , 28.7 , 28.7 ,
#         24.4 , 61.  , 39.4 , 51.2 , 51.2 , 35.4 , 14.2 , 15.7 , 29.9 ,
#         29.9 , 23.6 , 23.6 , 39.8 , 24.  , 78.7 , 31.5 , 57.1 , 33.  ,
#         34.  , 31.5 , 12.25, 37.4 , 19.7 , 39.8 , 39.  , 17.7 , 23.6 ,
#         10.2 , 19.7 ,  7.1 , 23.6 , 13.  , 31.5 , 50.  , 23.6 , 15.7 ,
#         16.1 , 17.7 ,  7.1 ,  0.4 , 55.1 , 23.6 ,  8.7 , 17.7 , 19.7 ,
#         39.  , 59.1 , 45.7 , 23.6 , 25.6 , 31.5 , 31.9 , 39.4 , 19.7 ,
#         19.7 ,  7.9 , 19.7 , 70.9 , 19.7 , 11.8 , 31.5 ,  7.9 , 11.8 ,
#         31.9 , 15.7 , 19.7 , 31.5 , 31.5 , 13.  , 40.6 , 31.5 , 20.9 ,
#         23.6 , 47.2 , 19.1 , 23.6 , 23.6 ,  5.1 , 19.7 , 15.7 , 19.7 ,
at', 'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Flat', 'Not flat', 'Flat', 'Not flat', 'Not flat',
#         'Flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Flat', 'Not flat'], dtype=object),
#  'Uniqueness': array(['Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Copy', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique'], dtype=object),
#  'is_signed': array(['signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed'], dtype=object),
#  'gallery': array(['gallery', 'gallery', 'gallery', 'gallery', 'gallery', 'gallery',
#         'independent', 'gallery', 'gallery', 'gallery', 'independent',
#         'gallery', 'gallery', 'gallery', 'independent', 'gallery',
#         'gallery', 'gallery', 'gallery', 'gallery', 'gallery', 'gallery',
#         'gallery', 'gallery', 'gallery', 'gallery', 'gallery', 'gallery',
#         'gallery', 'gallery', 'independent', 'gallery', 'gallery',
#         'independent', 'gallery', 'gallery', 'independent', 'gallery',
#         'gallery', 'independent', 'independent', 'gallery', 'gallery',
#         'gallery', 'independent', 'gallery', 'gallery', 'independent',
#         'independent', 'gallery', 'gallery', 'gallery', 'gallery',
#         'gallery', 'gallery', 'independent', 'gallery', 'gallery',
#         'gallery', 'gallery', 'gallery', 'independent', 'independent',
#         'gallery', 'independent', 'independent', 'independent',
#         'independent', 'gallery', 'independent', 'gallery', 'gallery',
#         'gallery', 'gallery', 'independent', 'gallery', 'gallery',
#         'gallery', 'gallery', 'gallery', 'gallery', 'gallery',
#         'independent', 'gallery', 'independent', 'gallery', 'gallery',
#         'gallery', 'gallery', 'gallery', 'gallery', 'gallery', 'gallery',
#         'independent', 'gallery', 'gallery', 'gallery', 'gallery',
#         'independent', 'independent'], dtype=object),
#  'painting': array(['acrylic', 'other', 'acrylic', 'acrylic', 'oil', 'oil', 'other',
#         'acrylic', 'acrylic', 'other', 'acrylic', 'oil', 'other',
#         'acrylic', 'other', 'other', 'acrylic', 'other', 'other', 'other',
#         'other', 'other', 'other', 'other', 'acrylic', 'other', 'other',
#         'other', 'other', 'other', 'other', 'other', 'other', 'other',
#         'oil', 'other', 'oil', 'acrylic', 'other', 'other', 'oil', 'oil',
#         'acrylic', 'other', 'other', 'other', 'other', 'other', 'other',
#         'acrylic', 'other', 'other', 'other', 'acrylic', 'acrylic',
#         'other', 'acrylic', 'acrylic', 'oil', 'other', 'other', 'other',
#         'oil', 'other', 'other', 'other', 'other', 'acrylic', 'other',
#         'acrylic', 'acrylic', 'other', 'oil', 'acrylic', 'oil', 'other',
#         'other', 'other', 'other', 'oil', 'other', 'other', 'acrylic',
#         'other', 'oil', 'oil', 'other', 'other', 'acrylic', 'acrylic',
#         'acrylic', 'other', 'other', 'other', 'acrylic', 'oil', 'other',
#         'acrylic', 'other', 'other'], dtype=object),
#  'description_present': array(['Present', 'No description', 'No description', 'Present',
#         'Present', 'Present', 'Present', 'No description', 'Present',
#         'Present', 'No description', 'Present', 'No description',
#         'Present', 'Present', 'No description', 'Present', 'Present',
#         'No description', 'Present', 'Present', 'Present', 'Present',
#         'Present', 'No description', 'Present', 'Present', 'Present',
#         'Present', 'No description', 'Present', 'No description',
#         'Present', 'Present', 'Present', 'Present', 'Present', 'Present',
#         'Present', 'Present', 'Present', 'Present', 'No description',
#         'No description', 'Present', 'No description', 'Present',
#         'Present', 'Present', 'No description', 'Present', 'Present',
#         'No description', 'Present', 'Present', 'Present',
#         'No description', 'Present', 'No description', 'Present',
#         'No description', 'Present', 'Present', 'No description',
#         'Present', 'Present', 'Present', 'Present', 'Present', 'Present',
#         'No description', 'Present', 'No description', 'Present',
#         'Present', 'No description', 'Present', 'Present',
#         'No description', 'Present', 'No description', 'Present',
#         'Present', 'No description', 'Present', 'Present',
#         'No description', 'No description', 'Present', 'No description',
#         'No description', 'Present', 'No description', 'Present',
#         'Present', 'No description', 'Present', 'Present',
#         'No description', 'Present'], dtype=object),
#  'location': array(['United States', 'other', 'France', 'other', 'other', 'other',
#         'other', 'France', 'France', 'France', 'other', 'France', 'other',
#         'France', 'France', 'France', 'other', 'France', 'France',
#         'France', 'France', 'France', 'other', 'other', 'France', 'France',
#         'United States', 'other', 'other', 'other', 'France', 'France',
#         'France', 'United States', 'other', 'other', 'other', 'France',
#         'France', 'other', 'France', 'Ukraine', 'United States', 'other',
#         'other', 'other', 'other', 'France', 'France', 'other', 'France',
#         'Spain', 'Spain', 'other', 'France', 'other', 'France', 'France',
#         'France', 'other', 'other', 'other', 'other', 'France', 'France',
#         'France', 'other', 'France', 'other', 'other', 'France', 'Ukraine',
#         'other', 'other', 'France', 'France', 'France', 'United States',
#         'other', 'Spain', 'France', 'France', 'other', 'Spain', 'other',
#         'other', 'other', 'France', 'Spain', 'other', 'France', 'other',
#         'France', 'other', 'other', 'France', 'Ukraine', 'France', 'Spain',
#         'other'], dtype=object)}

# %%
# output vector
y_debug = sample["price_numeric"].values

# %%
# train on sample
history = model.fit(
    X_debug,
    y_debug,
    epochs=5,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 24608020.0000
# Epoch 2/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24602184.0000
# Epoch 3/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24594642.0000
# Epoch 4/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24583696.0000
# Epoch 5/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24565816.0000

# %%
def load_image(path, img_size=(224, 224)):
    img = tf.io.read_file(path)  # read bytes
    img = tf.image.decode_image(img, channels=3, expand_animations=False)  # decode JPEG/PNG
    img = tf.image.resize(img, img_size)  # resize
    img = tf.cast(img, tf.float32)  # convert to float (0–255 range)
    return img

# %%
import tensorflow as tf

# 1. Input layer
image_input = tf.keras.Input(shape=(224, 224, 3), name="image")

# 2. Normalize pixels 0–255 → 0–1
x = tf.keras.layers.Rescaling(1/255.0)(image_input)

# 3. Convolutional layers
x = tf.keras.layers.Conv2D(32, (3,3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D()(x)

x = tf.keras.layers.Conv2D(64, (3,3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D()(x)

x = tf.keras.layers.Conv2D(128, (3,3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D()(x)

# 4. Flatten for dense layers
x = tf.keras.layers.Flatten()(x)

# 5. Dense layers
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)

# 6. Output layer (regression)
output = tf.keras.layers.Dense(1)(x)

# 7. Build and compile
image_model = tf.keras.Model(inputs=image_input, outputs=output)
image_model.compile(optimizer='adam', loss='mse')

# %%
sample = data.iloc[:100].copy()

# %%
X_images = tf.convert_to_tensor([load_image(p) for p in sample["image_path"]])

# %%
X_images.shape
# Out:
# TensorShape([100, 224, 224, 3])

# %%
y_images = sample["price_numeric"].values
print(y_images.shape)
# Out:
# (100,)

# %%
history = image_model.fit(
    X_images,
    y_images,
    epochs=5,      # small number to debug
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 317ms/step - loss: 2166356992.0000
# Epoch 2/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 305ms/step - loss: 2123328896.0000
# Epoch 3/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step - loss: 2093345280.0000
# Epoch 4/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step - loss: 2066524288.0000
# Epoch 5/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 297ms/step - loss: 2070920576.0000

# %%
import tensorflow as tf

# ============================================================
# 1) TABULAR INPUTS + PREPROCESSING
# ============================================================

# Create Input layers for tabular data
inputs = {}

# Numeric inputs
for col in numeric:
    inputs[col] = tf.keras.Input(shape=(1,), name=col)

# Categorical inputs
for col in categorical:
    inputs[col] = tf.keras.Input(shape=(1,), dtype=tf.string, name=col)

encoded_features = []

# --- Numeric preprocessing ---
numeric_inputs = [inputs[col] for col in numeric]
numeric_concat = tf.keras.layers.Concatenate()(numeric_inputs)
numeric_encoded = normalizer(numeric_concat)
encoded_features.append(numeric_encoded)

# --- Categorical preprocessing ---
for col in categorical:
    int_encoded = string_lookups[col](inputs[col])
    one_hot = one_hot_encoders[col](int_encoded)
    encoded_features.append(one_hot)

# Tabular feature vector
tabular_features = tf.keras.layers.Concatenate()(encoded_features)


# ============================================================
# 2) IMAGE INPUT + CNN BRANCH
# ============================================================

image_input = tf.keras.Input(shape=(224, 224, 3), name="image")

i = tf.keras.layers.Rescaling(1/255.0)(image_input)

i = tf.keras.layers.Conv2D(32, (3,3), activation='relu')(i)
i = tf.keras.layers.MaxPooling2D()(i)

i = tf.keras.layers.Conv2D(64, (3,3), activation='relu')(i)
i = tf.keras.layers.MaxPooling2D()(i)

i = tf.keras.layers.Conv2D(128, (3,3), activation='relu')(i)
i = tf.keras.layers.MaxPooling2D()(i)

i = tf.keras.layers.Flatten()(i)
i = tf.keras.layers.Dense(128, activation='relu')(i)
i = tf.keras.layers.Dense(64, activation='relu')(i)

image_features = i


# ============================================================
# 3) COMBINE TABULAR + IMAGE BRANCHES
# ============================================================

combined = tf.keras.layers.Concatenate()([tabular_features, image_features])

x = tf.keras.layers.Dense(128, activation='relu')(combined)
x = tf.keras.layers.Dense(64, activation='relu')(x)
output = tf.keras.layers.Dense(1)(x)


# ============================================================
# 4) BUILD THE MULTIMODAL MODEL
# ============================================================

all_inputs = list(inputs.values()) + [image_input]

multimodal_model = tf.keras.Model(inputs=all_inputs, outputs=output)

multimodal_model.compile(
    optimizer='adam',
    loss='mse'
)

multimodal_model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ rescaling_1 (Rescaling)       │ (None, 224, 224, 3)       │               0 │ image[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 222, 222, 32)      │             896 │ rescaling_1[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 111, 111, 32)      │               0 │ conv2d_3[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 109, 109, 64)      │          18,496 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 54, 54, 64)        │               0 │ conv2d_4[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 52, 52, 128)       │          73,856 │ max_pooling2d_4[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Height (InputLayer)           │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Width (InputLayer)            │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ age (InputLayer)              │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ years_selling (InputLayer)    │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ type (InputLayer)             │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gender_guessed (InputLayer)   │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ is_flat (InputLayer)          │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Uniqueness (InputLayer)       │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ is_signed (InputLayer)        │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gallery (InputLayer)          │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ painting (InputLayer)         │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ description_present           │ (None, 1)                 │               0 │ -                          │
# │ (InputLayer)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ location (InputLayer)         │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 26, 26, 128)       │               0 │ conv2d_5[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_8 (Concatenate)   │ (None, 4)                 │               0 │ Height[0][0], Width[0][0], │
# │                               │                           │                 │ age[0][0],                 │
# │                               │                           │                 │ years_selling[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ string_lookup_18              │ (None, 1)                 │               0 │ type[0][0]                 │
# │ (StringLookup)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ string_lookup_19              │ (None, 1)                 │               0 │ gender_guessed[0][0]       │
# │ (StringLookup)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ string_lookup_20              │ (None, 1)                 │               0 │ is_flat[0][0]              │
# │ (StringLookup)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ string_lookup_21              │ (None, 1)                 │               0 │ Uniqueness[0][0]           │
# │ (StringLookup)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ string_lookup_22              │ (None, 1)                 │               0 │ is_signed[0][0]            │
# │ (StringLookup)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ string_lookup_23              │ (None, 1)                 │               0 │ gallery[0][0]              │
# │ (StringLookup)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ string_lookup_24              │ (None, 1)                 │               0 │ painting[0][0]             │
# │ (StringLookup)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ string_lookup_25              │ (None, 1)                 │               0 │ description_present[0][0]  │
# │ (StringLookup)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ string_lookup_26              │ (None, 1)                 │               0 │ location[0][0]             │
# │ (StringLookup)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_1 (Flatten)           │ (None, 86528)             │               0 │ max_pooling2d_5[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ normalization_3               │ (None, 4)                 │               9 │ concatenate_8[0][0]        │
# │ (Normalization)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ category_encoding_18          │ (None, 30)                │               0 │ string_lookup_18[1][0]     │
# │ (CategoryEncoding)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ category_encoding_19          │ (None, 4)                 │               0 │ string_lookup_19[1][0]     │
# │ (CategoryEncoding)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ category_encoding_20          │ (None, 3)                 │               0 │ string_lookup_20[1][0]     │
# │ (CategoryEncoding)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ category_encoding_21          │ (None, 3)                 │               0 │ string_lookup_21[1][0]     │
# │ (CategoryEncoding)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ category_encoding_22          │ (None, 3)                 │               0 │ string_lookup_22[1][0]     │
# │ (CategoryEncoding)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ category_encoding_23          │ (None, 3)                 │               0 │ string_lookup_23[1][0]     │
# │ (CategoryEncoding)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ category_encoding_24          │ (None, 4)                 │               0 │ string_lookup_24[1][0]     │
# │ (CategoryEncoding)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ category_encoding_25          │ (None, 3)                 │               0 │ string_lookup_25[1][0]     │
# │ (CategoryEncoding)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ category_encoding_26          │ (None, 6)                 │               0 │ string_lookup_26[1][0]     │
# │ (CategoryEncoding)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_19 (Dense)              │ (None, 128)               │      11,075,712 │ flatten_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_9 (Concatenate)   │ (None, 63)                │               0 │ normalization_3[1][0],     │
# │                               │                           │                 │ category_encoding_18[1][0… │
# │                               │                           │                 │ category_encoding_19[1][0… │
# │                               │                           │                 │ category_encoding_20[1][0… │
# │                               │                           │                 │ category_encoding_21[1][0… │
# │                               │                           │                 │ category_encoding_22[1][0… │
# │                               │                           │                 │ category_encoding_23[1][0… │
# │                               │                           │                 │ category_encoding_24[1][0… │
# │                               │                           │                 │ category_encoding_25[1][0… │
# │                               │                           │                 │ category_encoding_26[1][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_20 (Dense)              │ (None, 64)                │           8,256 │ dense_19[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_10 (Concatenate)  │ (None, 127)               │               0 │ concatenate_9[0][0],       │
# │                               │                           │                 │ dense_20[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_21 (Dense)              │ (None, 128)               │          16,384 │ concatenate_10[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_22 (Dense)              │ (None, 64)                │           8,256 │ dense_21[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_23 (Dense)              │ (None, 1)                 │              65 │ dense_22[0][0]             │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 11,201,930 (42.73 MB)
#  Trainable params: 11,201,921 (42.73 MB)
#  Non-trainable params: 9 (40.00 B)

# %%
sample = data.iloc[:100].copy()
sample.head()
# Out:
#           type gender_guessed  Height  Width   is_flat  age  years_selling  \
# 0  Unique work         female    27.6   27.6  Not flat  0.0            1.0
# 1  Unique work         female    19.7   19.7  Not flat  0.0            3.0
# 2  Unique work         female    23.6   23.6  Not flat  0.0            3.0
# 3  Unique work         female    15.7   11.8  Not flat  4.0            5.0
# 4  Unique work        unknown    15.7   15.7  Not flat  4.0            5.0
#
#   Uniqueness is_signed      gallery  price_numeric painting  \
# 0     Unique    signed  independent         3158.0    other
# 1     Unique    signed  independent         2065.0    other
# 2     Unique    signed  independent         3522.0    other
# 3     Unique    signed      gallery          644.0      oil
# 4     Unique    signed  independent          838.0    other
#
#   description_present location                     image_path
# 0             Present   France  images_thesis\2313827_1_m.jpg
# 1             Present   France  images_thesis\2328028_1_m.jpg
# 2             Present   France  images_thesis\2299335_1_m.jpg
# 3             Present    other  images_thesis\1118562_1_m.jpg
# 4             Present   France  images_thesis\1241121_1_m.jpg

# %%
X_multi = {}

# numeric
for col in numeric:
    X_multi[col] = sample[col].values

# categorical
for col in categorical:
    X_multi[col] = sample[col].values

# %%
X_images = tf.convert_to_tensor([
    load_image(p) for p in sample["image_path"]
])

# %%
X_images.shape
# Out:
# TensorShape([100, 224, 224, 3])

# %%
X_multi["image"] = X_images
X_multi
# Out:
# {'Height': array([27.6, 19.7, 23.6, 15.7, 15.7, 31.5, 19.7, 19.3, 47.2, 31.9,  8. ,
#         31.9, 31.5, 28.7, 31.5, 59.1,  7.9, 14.6, 35.4, 40. , 63.8, 27.6,
#         24. , 63. , 47.2, 48. , 36. , 31.9, 25.6, 16.5, 31.5, 31.9, 35.4,
#         12.6, 19.7, 23.6, 15.7, 29.5, 23.6, 16.5, 23.6, 27.6, 39.4,  7.9,
#         21.7, 39.4, 45.7, 11.8, 15.7, 47.2, 21.7, 39.4, 28.7, 28.7,  9.8,
#         48. , 15.7, 31.5, 31.5, 28.7, 27.6, 28.7, 23.6, 47.2, 15.7, 16. ,
unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work',
#         'Unique work', 'Unique work', 'Unique work', 'Unique work'],
#        dtype=object),
#  'gender_guessed': array(['female', 'female', 'female', 'female', 'unknown', 'male',
#         'female', 'unknown', 'male', 'male', 'male', 'male', 'female',
#         'male', 'female', 'unknown', 'male', 'male', 'male', 'male',
#         'unknown', 'unknown', 'unknown', 'female', 'male', 'female',
#         'unknown', 'male', 'unknown', 'female', 'female', 'female', 'male',
#         'male', 'unknown', 'male', 'unknown', 'unknown', 'male', 'female',
#         'male', 'female', 'unknown', 'male', 'male', 'female', 'female',
#         'unknown', 'male', 'unknown', 'female', 'unknown', 'male', 'male',
#         'female', 'male', 'male', 'female', 'male', 'female', 'male',
#         'male', 'male', 'unknown', 'male', 'female', 'male', 'female',
#         'female', 'male', 'unknown', 'female', 'male', 'male', 'male',
#         'female', 'unknown', 'female', 'male', 'unknown', 'unknown',
#         'unknown', 'male', 'unknown', 'male', 'unknown', 'female', 'male',
#         'male', 'male', 'male', 'unknown', 'male', 'male', 'unknown',
#         'unknown', 'male', 'male', 'male', 'unknown'], dtype=object),
#  'is_flat': array(['Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Flat',
#         'Not flat', 'Flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Flat', 'Not flat',
#         'Not flat', 'Flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat', 'Not flat', 'Not flat',
#         'Not flat', 'Not flat', 'Not flat'], dtype=object),
#  'Uniqueness': array(['Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique', 'Unique', 'Unique',
#         'Unique', 'Unique', 'Unique', 'Unique'], dtype=object),
#  'is_signed': array(['signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'not signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'not signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'not signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'signed',
#         'signed', 'signed', 'signed', 'signed', 'signed', 'not signed',
#         'signed', 'signed', 'signed', 'signed'], dtype=object),
#  'gallery': array(['independent', 'independent', 'independent', 'gallery',
#         'independent', 'independent', 'independent', 'gallery', 'gallery',
#         'gallery', 'gallery', 'gallery', 'independent', 'gallery',
#         'independent', 'gallery', 'gallery', 'gallery', 'independent',
#         'gallery', 'gallery', 'gallery', 'independent', 'independent',
#         'gallery', 'gallery', 'gallery', 'gallery', 'gallery', 'gallery',
#         'independent', 'independent', 'independent', 'gallery', 'gallery',
#         'gallery', 'gallery', 'gallery', 'gallery', 'gallery',
#         'independent', 'gallery', 'gallery', 'independent', 'gallery',
#         'gallery', 'gallery', 'gallery', 'independent', 'gallery',
#         'gallery', 'gallery', 'gallery', 'gallery', 'gallery', 'gallery',
#         'independent', 'gallery', 'gallery', 'independent', 'gallery',
#         'gallery', 'independent', 'gallery', 'gallery', 'gallery',
#         'gallery', 'gallery', 'independent', 'gallery', 'gallery',
#         'independent', 'gallery', 'gallery', 'gallery', 'independent',
#         'gallery', 'independent', 'gallery', 'gallery', 'gallery',
#         'gallery', 'gallery', 'gallery', 'gallery', 'gallery',
#         'independent', 'gallery', 'gallery', 'gallery', 'independent',
#         'gallery', 'independent', 'gallery', 'gallery', 'gallery',
#         'gallery', 'gallery', 'gallery', 'gallery'], dtype=object),
#  'painting': array(['other', 'other', 'other', 'oil', 'other', 'acrylic', 'acrylic',
#         'other', 'acrylic', 'oil', 'acrylic', 'other', 'acrylic', 'other',
#         'oil', 'acrylic', 'acrylic', 'oil', 'acrylic', 'acrylic',
#         'acrylic', 'acrylic', 'acrylic', 'acrylic', 'other', 'other',
#         'other', 'other', 'other', 'other', 'acrylic', 'other', 'other',
#         'other', 'acrylic', 'other', 'acrylic', 'other', 'acrylic',
#         'other', 'other', 'other', 'other', 'other', 'acrylic', 'oil',
#         'other', 'oil', 'oil', 'other', 'oil', 'acrylic', 'acrylic',
#         'acrylic', 'acrylic', 'acrylic', 'other', 'acrylic', 'acrylic',
#         'other', 'acrylic', 'oil', 'oil', 'acrylic', 'other', 'acrylic',
#         'oil', 'acrylic', 'oil', 'other', 'other', 'acrylic', 'other',
#         'other', 'acrylic', 'other', 'other', 'other', 'oil', 'other',
#         'other', 'oil', 'acrylic', 'other', 'other', 'acrylic', 'other',
#         'other', 'other', 'oil', 'other', 'other', 'oil', 'other', 'oil',
#         'other', 'acrylic', 'acrylic', 'oil', 'other'], dtype=object),
#  'description_present': array(['Present', 'Present', 'Present', 'Present', 'Present', 'Present',
#         'Present', 'Present', 'Present', 'No description', 'Present',
#         'No description', 'Present', 'Present', 'Present', 'Present',
#         'No description', 'Present', 'Present', 'Present',
#         'No description', 'No description', 'Present', 'Present',
#         'No description', 'Present', 'No description', 'No description',
#         'Present', 'No description', 'Present', 'Present',
#         'No description', 'Present', 'No description', 'No description',
#         'No description', 'Present', 'Present', 'No description',
#         'Present', 'Present', 'No description', 'No description',
#         'Present', 'No description', 'Present', 'Present',
#         'No description', 'Present', 'Present', 'Present',
#         'No description', 'No description', 'No description',
#         'No description', 'No description', 'Present', 'No description',
#         'No description', 'Present', 'No description', 'Present',
#         'No description', 'No description', 'Present', 'No description',
#         'Present', 'Present', 'No description', 'No description',
#         'Present', 'Present', 'No description', 'Present',
#         'No description', 'No description', 'Present', 'Present',
#         'Present', 'No description', 'No description', 'No description',
#         'Present', 'No description', 'Present', 'Present', 'Present',
#         'No description', 'Present', 'No description', 'No description',
#         'Present', 'Present', 'Present', 'No description',
#         'No description', 'Present', 'No description', 'No description'],
#        dtype=object),
#  'location': array(['France', 'France', 'France', 'other', 'France', 'other', 'other',
#         'France', 'other', 'France', 'United States', 'other', 'other',
#         'other', 'other', 'France', 'France', 'other', 'other',
#         'United States', 'other', 'France', 'France', 'Spain', 'France',
#         'United States', 'other', 'France', 'France', 'Spain', 'France',
#         'France', 'Spain', 'France', 'France', 'France', 'France',
#         'France', 'France', 'other', 'France', 'other', 'France',
#         'Ukraine', 'Spain', 'France', 'France', 'Ukraine', 'other',
#         'France', 'France', 'France', 'France', 'France', 'France',
#         'other', 'other', 'other', 'other', 'Ukraine', 'France', 'France',
#         'other', 'France', 'France', 'United States', 'France',
#         'United States', 'other', 'other', 'United States', 'France',
#         'other', 'France', 'other', 'France', 'other', 'France', 'Spain',
#         'Ukraine', 'France', 'France', 'France', 'Ukraine', 'other',
#         'France', 'other', 'France', 'France', 'other', 'other', 'France',
#          [[1.33004135e+02, 1.11352348e+02, 9.01893997e+01],
#           [1.43434280e+02, 1.15456604e+02, 8.68006821e+01],
#           [1.45370544e+02, 1.16000000e+02, 8.55128479e+01],
#           ...,
#           [1.68571106e+02, 1.42790741e+02, 1.10058350e+02],
#           [1.85844101e+02, 1.63866440e+02, 1.32377609e+02],
#           [1.84542770e+02, 1.64542770e+02, 1.37542770e+02]],
#
#          ...,
#
#          [[1.55239014e+02, 1.29549240e+02, 1.02704338e+02],
#           [1.45845398e+02, 1.18845390e+02, 8.98453903e+01],
#           [1.53013611e+02, 1.22384148e+02, 9.28969421e+01],
#           ...,
#           [2.01103836e+02, 1.72440094e+02, 1.37431290e+02],
#           [2.01117813e+02, 1.73117813e+02, 1.34298965e+02],
#           [1.82985352e+02, 1.54985352e+02, 1.15985352e+02]],
#
#          [[1.50057327e+02, 1.25731438e+02, 9.95684891e+01],
#           [1.50294525e+02, 1.23294525e+02, 9.42945251e+01],
#           [1.53985931e+02, 1.24985939e+02, 9.33564758e+01],
#           ...,
#           [1.97044678e+02, 1.69044678e+02, 1.32044678e+02],
#           [1.90477417e+02, 1.62477417e+02, 1.24977661e+02],
#           [1.91978790e+02, 1.63978790e+02, 1.24978790e+02]],
#
#          [[1.55216125e+02, 1.29216125e+02, 1.03890228e+02],
#           [1.50636688e+02, 1.23636688e+02, 9.46366882e+01],
#           [1.50195862e+02, 1.21195847e+02, 8.95663834e+01],
#           ...,
#           [1.97228790e+02, 1.69228790e+02, 1.32228790e+02],
#           [1.95572220e+02, 1.67572220e+02, 1.30572220e+02],
#           [1.99886215e+02, 1.71886215e+02, 1.34886215e+02]]],
#
#
#         ...,
#
#
#         [[[1.30000000e+01, 1.30000000e+01, 1.30000000e+01],
#           [1.30000000e+01, 1.30000000e+01, 1.30000000e+01],
#           [1.30000000e+01, 1.30000000e+01, 1.30000000e+01],
#           ...,
#           [1.30000000e+01, 1.30000000e+01, 1.30000000e+01],
#           [1.30000000e+01, 1.30000000e+01, 1.30000000e+01],
#           [1.20000000e+01, 1.20000000e+01, 1.20000000e+01]],
#
#          [[1.20000000e+01, 1.20000000e+01, 1.20000000e+01],
#           [1.20000000e+01, 1.20000000e+01, 1.20000000e+01],
#           [1.20000000e+01, 1.20000000e+01, 1.20000000e+01],
#           ...,
#           [1.20000000e+01, 1.20000000e+01, 1.20000000e+01],
#           [1.20000000e+01, 1.20000000e+01, 1.20000000e+01],
#           [1.20000000e+01, 1.20000000e+01, 1.20000000e+01]],
#
#          [[1.01852674e+01, 1.01852674e+01, 1.01852674e+01],
#           [1.10000000e+01, 1.10000000e+01, 1.10000000e+01],
#           [1.18147326e+01, 1.18147326e+01, 1.18147326e+01],
#           ...,
#           [1.19210033e+01, 1.19210033e+01, 1.19210033e+01],
#           [1.20000000e+01, 1.20000000e+01, 1.20000000e+01],
#           [1.20000000e+01, 1.20000000e+01, 1.20000000e+01]],
#
#          ...,
#
#          [[9.81469727e+00, 9.81469727e+00, 9.81469727e+00],
#           [9.00000000e+00, 9.00000000e+00, 9.00000000e+00],
#           [9.00000000e+00, 9.00000000e+00, 9.00000000e+00],
#           ...,
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#          [
#
#
#         [[[5.33517303e+01, 1.26351730e+02, 7.03517303e+01],
#           [5.84531250e+01, 1.31926346e+02, 7.56897354e+01],
#           [5.94997292e+01, 1.36682770e+02, 7.89550858e+01],
#           ...,
#           [4.40214539e+01, 8.44321365e+01, 9.99859848e+01],
#           [4.03514061e+01, 8.05848236e+01, 9.61087418e+01],
#           [4.16772614e+01, 8.58956604e+01, 1.00008560e+02]],
#
#          [[5.32165184e+01, 1.26216515e+02, 7.02165146e+01],
#           [6.01588898e+01, 1.33632095e+02, 7.73955002e+01],
#           [5.96666031e+01, 1.36849640e+02, 7.91219635e+01],
#           ...,
#           [3.47996483e+01, 1.03099518e+02, 1.27838379e+02],
#           [3.65717506e+01, 1.01297157e+02, 1.27169609e+02],
#           [3.64642677e+01, 1.02083176e+02, 1.25789757e+02]],
#
#          [[5.61423187e+01, 1.29142319e+02, 7.31423187e+01],
#           [5.91414337e+01, 1.32614655e+02, 7.65708084e+01],
#           [6.03089218e+01, 1.36764282e+02, 8.07138290e+01],
#           ...,
#           [4.09018021e+01, 1.07357124e+02, 1.36629471e+02],
#           [4.01464386e+01, 9.96195831e+01, 1.29753540e+02],
#           [3.96001434e+01, 9.76869049e+01, 1.26617714e+02]],
#
#          ...,
#
#          [[7.59034271e+01, 1.29274033e+02, 1.09088730e+02],
#           [6.81194000e+01, 1.26497467e+02, 1.04497467e+02],
#           [7.22790527e+01, 1.34279053e+02, 1.12734413e+02],
#           ...,
#           [1.04999657e+02, 1.35454971e+02, 6.84549789e+01],
#           [1.14639191e+02, 1.41290207e+02, 6.85780487e+01],
#           [1.26404266e+02, 1.50404266e+02, 7.42659607e+01]],
#
#          [[7.64670868e+01, 1.30958160e+02, 1.10212624e+02],
#           [6.10709839e+01, 1.20070984e+02, 9.80709839e+01],
#           [6.27336922e+01, 1.24733696e+02, 1.03189049e+02],
#           ...,
#           [1.09611786e+02, 1.39323196e+02, 7.26951523e+01],
#           [1.09015686e+02, 1.36725403e+02, 6.54888306e+01],
#           [1.17458549e+02, 1.43209778e+02, 6.97209473e+01]],
#
#          [[5.67908287e+01, 1.11281906e+02, 9.05363693e+01],
#           [7.07859726e+01, 1.29022583e+02, 1.07022583e+02],
#           [7.18577957e+01, 1.30857788e+02, 1.10313148e+02],
#           ...,
#           [1.02860756e+02, 1.31860748e+02, 6.58163910e+01],
#           [1.05565392e+02, 1.35565399e+02, 6.53166656e+01],
#           [1.08837097e+02, 1.35837097e+02, 6.48370972e+01]]]],
#        shape=(100, 224, 224, 3), dtype=float32)>}

# %%
y_multi = sample["price_numeric"].values

# %%
multimodal_model.fit(
    X_multi,
    y_multi,
    epochs=5,
    batch_size=16
)
# Out:
# Epoch 1/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 302ms/step - loss: 2166754048.0000
# Epoch 2/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - loss: 2091914752.0000
# Epoch 3/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 299ms/step - loss: 2134672000.0000
# Epoch 4/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - loss: 2073891200.0000
# Epoch 5/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - loss: 2077431552.0000
